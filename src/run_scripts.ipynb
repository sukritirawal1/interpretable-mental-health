# %%
# !pip install bitsandbytes peft

# %%
# !python finetune_mentallama.py \
  --data_path /home/sagemaker-user/interpretable-mental-health/train_data/dreaddit/train.csv \
  --model_output_path ../output/mentallama_DR_dreaddit_finetuned.pt \
  --batch_size 2 --epochs 3 --cuda
# Out:
# 2025-04-27 21:31:58.919806: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745789518.940894   17680 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745789518.947569   17680 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 21:31:58.968073: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Cell 1
import pandas as pd
import os

# %%
data_path = "/home/sagemaker-user/MentalLLaMA/train_data/DR/train.csv"

# %%
# Cell 3
if os.path.isfile(data_path):
    print(f"File found at: {data_path}")
    data = pd.read_csv(data_path)
    print(f"File loaded successfully. Number of rows: {len(data)}")
    print("Columns found:", list(data.columns))
else:
    print(f"File not found: {data_path}")
# Out:
# File found at: /home/sagemaker-user/MentalLLaMA/train_data/instruction_data/DR/train.csv
# File loaded successfully. Number of rows: 1003
# Columns found: ['query', 'gpt-3.5-turbo']

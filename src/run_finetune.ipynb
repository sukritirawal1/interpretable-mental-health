# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
sys.path.append('RTC:interpretable-mental-health/src/')
from bart_score import BARTScorer

# %%
# !pip install evaluate
# !pip install transformers peft accelerate bitsandbytes sentencepiece

# %%
# !python /content/drive/MyDrive/ANLP-Project/Interpretable-Mental-Health/interpretable-mental-health/src/finetune_mentallama.py \
  --model_name klyang/MentaLLaMA-chat-7B \
  --data_path /content/drive/MyDrive/ANLP-Project/Interpretable-Mental-Health/interpretable-mental-health/src/train_data/instruction_data/DR/train.csv \
  --compare_type original \
  --alpha 0.6 \
  --batch_size 1 \
  --epochs 1 \
  --cuda
# Out:
# 2025-04-20 04:29:47.307036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745123387.328317   18181 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745123387.334784   18181 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Epoch 1:   0% 0/1003 [00:00<?, ?it/s]`use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Epoch 1:   0% 0/1003 [00:02<?, ?it/s]
# ...

# %%
# import pandas as pd

# path = "/content/drive/MyDrive/ANLP-Project/Interpretable-Mental-Health/interpretable-mental-health/src/train_data/instruction_data/DR/train.csv"
# df = pd.read_csv(path)
# print(f"✅ Rows: {len(df)}")
# df.head()
# Out:
# ✅ Rows: 1003
#                                                query  \
# 0  Consider this post: "How to avoid a relapse? I...
# 1  Consider this post: "This is how I feel and I ...
# 2  Consider this post: "Advice for getting back i...
# 3  Consider this post: "Having a really bad stret...
# 4  Consider this post: "I dont understand how peo...
#
#                                        gpt-3.5-turbo
# 0  Yes, the poster suffers from depression. Reaso...
# 1  Yes, the poster suffers from depression. Reaso...
# 2  Yes, the poster suffers from depression. Reaso...
# 3  Yes, the poster suffers from depression. Reaso...
# 4  Yes, the poster suffers from depression. Reaso...
